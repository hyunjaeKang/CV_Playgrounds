# %% [markdown]
# # triangle-splatting :: Custom data :: hanauma_bay
#
# -----
# - Conda env : [triangle_splatting2](README.md#setup-a-conda-environment)
# -----

# %% [markdown]
# ### Check system

# %%
# !nvidia-smi
# Out:
# Wed Oct 15 15:28:02 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 575.57.08              Driver Version: 575.57.08      CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 2080 Ti     On  |   00000000:01:00.0  On |                  N/A |
# | 22%   41C    P8             31W /  250W |     543MiB /  11264MiB |     33%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2079      G   /usr/lib/xorg/Xorg                      278MiB |
# |    0   N/A  N/A            2259      G   /usr/bin/gnome-shell                     36MiB |
# |    0   N/A  N/A            3654      G   /usr/share/code/code                    169MiB |
# |    0   N/A  N/A            3715      G   ...ersion=20251014-170058.618000         43MiB |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### Download a video

# %%
import os
from pathlib import Path

Path("./temp_data").mkdir(exist_ok=True, parents=True)

# %%
import gdown

VIDEO_NAME = "hanauma_bay"

FPS = 2
RES = 4
id = "1eNb_GkkOKUSq_6cS8g4_cuPJ9CZvPBkQ"
vid_path = f"./temp_data/{VIDEO_NAME}.mov"

if not os.path.exists(vid_path):
    gdown.download(id=id, output = vid_path)
else:
    print(f"{vid_path} already is downloaded")
# Out:
# ./temp_data/hanauma_bay.mov already is downloaded

# %% [markdown]
# ### Extract images from the video

# %%
DATASET_DIR_PATH = f"./temp_data/{VIDEO_NAME}"
IMAGES_DIR_PATH = os.path.join(DATASET_DIR_PATH, "images")
DATABASE_PATH = os.path.join(DATASET_DIR_PATH, "database.db")

if not os.path.exists(IMAGES_DIR_PATH):
    Path(IMAGES_DIR_PATH).mkdir(exist_ok=True, parents=True)
    # !ffmpeg -i $vid_path -vf fps=$FPS $IMAGES_DIR_PATH/frame_%04d.jpg
else:
    print(f"{IMAGES_DIR_PATH} already is extracted")
# Out:
# ./temp_data/hanauma_bay/images already is extracted

# %% [markdown]
# ### Colmap :: Feature Extraction & Matching & Reconstruction

# %%
SPARSE_DIR = os.path.join(DATASET_DIR_PATH, "sparse")
Path(SPARSE_DIR).mkdir(exist_ok=True, parents=True)

if not os.path.exists(DATABASE_PATH):
    # Colmap Feature Extraction
    # !colmap feature_extractor \
        --database_path $DATABASE_PATH \
        --image_path $IMAGES_DIR_PATH  --ImageReader.camera_model PINHOLE
    # !colmap sequential_matcher \
        --database_path $DATABASE_PATH
    # !colmap mapper \
        --database_path $DATABASE_PATH \
        --image_path $IMAGES_DIR_PATH \
        --output_path $SPARSE_DIR
else:
    print(f"{DATABASE_PATH} already is extracted and reconstructed")
# Out:
# ./temp_data/hanauma_bay/database.db already is extracted and reconstructed

# %% [markdown]
# ### Triangle-Splatting :: Training (Outdoor mode)

# %%
DATASET_DIR_PATH
OUTDOOR_OUTPUR_DIR_PATH = f"./temp_result/{VIDEO_NAME}_outdoor"
print(DATASET_DIR_PATH)
print(OUTDOOR_OUTPUR_DIR_PATH)

# !CUDA_VISIBLE_DEVICES=0 python temp_triangle-splatting2/train.py -s $DATASET_DIR_PATH -m $OUTDOOR_OUTPUR_DIR_PATH -r $RES --eval
# Out:
# ./temp_data/hanauma_bay
# ./temp_result/hanauma_bay_outdoor
# Optimizing ./temp_result/hanauma_bay_outdoor
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/lpips/weights/v0.1/vgg.pth
# Output folder: ./temp_result/hanauma_bay_outdoor [15/10 07:50:32]
# Tensorboard not available: not logging progress [15/10 07:50:32]
# Using cache found in /home/hyunjae/.cache/torch/hub/yvanyin_metric3d_main
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /home/hyunjae/.cache/torch/hub/yvanyin_metric3d_main/mono/model/backbones/ViT_DINO.py:248: FutureWarning: xformers.components is deprecated and is not maintained anymore. It might be removed in a future version of xFormers
#   from xformers.components.attention import ScaledDotProduct
# xFormers not available
# xFormers not available
# Reading camera 46/46 [15/10 07:53:05]
# Loading Training Cameras [15/10 07:53:05]
# Loading Test Cameras [15/10 07:53:06]
# Training progress:   2%|      | 500/30000 [00:17<17:42, 27.76it/s, Loss=0.49812]tensor(0., device='cuda:0') [15/10 07:53:24]
# Training progress:   3%|▏    | 1000/30000 [00:33<06:17, 76.74it/s, Loss=0.46485]
# [ITER 1000] Evaluating test: L1 0.4074143717686335 PSNR 5.646192630132039 SSIM 0.18437084307273227 LPIPS 0.6670017937819163 [15/10 07:53:40]
#
# [ITER 1000] Evaluating train: L1 0.43309379220008853 PSNR 5.373190116882324 SSIM 0.17226925864815712 LPIPS 0.6725606322288513 [15/10 07:53:40]
# tensor(0., device='cuda:0') [15/10 07:53:40]
# Training progress:   5%|▎    | 1500/30000 [00:49<10:14, 46.37it/s, Loss=0.23903]tensor(0., device='cuda:0') [15/10 07:53:56]
# Training progress:   7%|▎    | 2000/30000 [00:57<06:56, 67.18it/s, Loss=0.24492]
# [ITER 2000] Evaluating test: L1 0.11715658257404962 PSNR 15.8207426071167 SSIM 0.5000450164079666 LPIPS 0.5847352047761281 [15/10 07:54:04]
#
# [ITER 2000] Evaluating train: L1 0.19303250312805176 PSNR 14.84812788963318 SSIM 0.42866545617580415 LPIPS 0.602364182472229 [15/10 07:54:04]
# tensor(0., device='cuda:0') [15/10 07:54:04]
# Training progress:   8%|▍    | 2500/30000 [01:05<06:17, 72.90it/s, Loss=0.16270]tensor(0., device='cuda:0') [15/10 07:54:11]
# Training progress:  10%|▌    | 3000/30000 [01:15<15:26, 29.13it/s, Loss=0.15855]
# [ITER 3000] Evaluating test: L1 0.1000265267988046 PSNR 16.572047869364418 SSIM 0.5255891283353169 LPIPS 0.5683083037535349 [15/10 07:54:21]
#
# [ITER 3000] Evaluating train: L1 0.18337341099977494 PSNR 15.609583568573 SSIM 0.4509611399844289 LPIPS 0.5890707612037659 [15/10 07:54:21]
# tensor(0., device='cuda:0') [15/10 07:54:21]
# Training progress:  12%|▌    | 3500/30000 [01:29<09:30, 46.46it/s, Loss=0.16000]tensor(0., device='cuda:0') [15/10 07:54:36]
# Training progress:  13%|▋    | 4000/30000 [01:41<14:28, 29.95it/s, Loss=0.13738]
# [ITER 4000] Evaluating test: L1 0.08732713386416435 PSNR 17.59474500020345 SSIM 0.54190161327521 LPIPS 0.5394547879695892 [15/10 07:54:48]
#
# [ITER 4000] Evaluating train: L1 0.17219929546117785 PSNR 17.158743858337402 SSIM 0.476939198654145 LPIPS 0.5532994627952575 [15/10 07:54:48]
# tensor(0., device='cuda:0') [15/10 07:54:48]
# Training progress:  15%|▊    | 4500/30000 [01:53<06:25, 66.15it/s, Loss=0.12854]tensor(0., device='cuda:0') [15/10 07:54:59]
# Training progress:  17%|▊    | 5000/30000 [02:01<04:43, 88.03it/s, Loss=0.12306]
# Training progress:  97%|███▊| 29000/30000 [09:53<00:25, 39.53it/s, Loss=0.07302]
# [ITER 29000] Evaluating test: L1 0.10839563359816869 PSNR 15.855941613515217 SSIM 0.4604265342156092 LPIPS 0.4894915968179703 [15/10 08:03:00]
#
# [ITER 29000] Evaluating train: L1 0.15458189994096758 PSNR 19.790348529815674 SSIM 0.6333452766411938 LPIPS 0.38763604760169984 [15/10 08:03:00]
# tensor(0.6950, device='cuda:0') [15/10 08:03:00]
# Training progress:  98%|███▉| 29500/30000 [10:02<00:09, 54.90it/s, Loss=0.07787]tensor(0.7050, device='cuda:0') [15/10 08:03:09]
# Training progress: 100%|███▉| 29950/30000 [10:10<00:00, 52.29it/s, Loss=0.06799]29960 [15/10 08:03:17]
# Training progress: 100%|████| 30000/30000 [10:11<00:00, 49.02it/s, Loss=0.08220]
#
# [ITER 30000] Evaluating test: L1 0.1087958961725235 PSNR 15.82453457514445 SSIM 0.4558909883101781 LPIPS 0.4919080237547556 [15/10 08:03:18]
#
# [ITER 30000] Evaluating train: L1 0.15503025576472285 PSNR 19.72790231704712 SSIM 0.6270866697304882 LPIPS 0.3923243641853333 [15/10 08:03:18]
# tensor(0., device='cuda:0') [15/10 08:03:18]
# Training is done [15/10 08:03:19]
#
# Training complete. [15/10 08:03:19]

# %% [markdown]
# ### Triangle-Splatting :: Rendering (Outdoor mode)

# %%
# !CUDA_VISIBLE_DEVICES=0 python temp_triangle-splatting2/render.py -m $OUTDOOR_OUTPUR_DIR_PATH -r $RES -s $DATASET_DIR_PATH
# Out:
# Looking for config file in ./temp_result/hanauma_bay_outdoor/cfg_args
# Config file found: ./temp_result/hanauma_bay_outdoor/cfg_args
# Rendering ./temp_result/hanauma_bay_outdoor
# Loading trained model at iteration 30000 [15/10 08:03:22]
# Using cache found in /home/hyunjae/.cache/torch/hub/yvanyin_metric3d_main
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /home/hyunjae/.cache/torch/hub/yvanyin_metric3d_main/mono/model/backbones/ViT_DINO.py:248: FutureWarning: xformers.components is deprecated and is not maintained anymore. It might be removed in a future version of xFormers
#   from xformers.components.attention import ScaledDotProduct
# xFormers not available
# xFormers not available
# Reading camera 46/46 [15/10 08:03:30]
# Loading Training Cameras [15/10 08:03:30]
# Loading Test Cameras [15/10 08:03:31]
# Rendering progress: 100%|███████████████████████| 40/40 [00:02<00:00, 13.97it/s]
# Rendering progress: 100%|█████████████████████████| 6/6 [00:00<00:00, 15.42it/s]

# %% [markdown]
# ### Triangle-Splatting :: Create a video (Outdoor mode)

# %%
# !CUDA_VISIBLE_DEVICES=0 python temp_triangle-splatting2/create_video.py  -s $DATASET_DIR_PATH -m $OUTDOOR_OUTPUR_DIR_PATH -r $RES --save_as $OUTDOOR_OUTPUR_DIR_PATH/output_video
# Out:
# Looking for config file in ./temp_result/hanauma_bay_outdoor/cfg_args
# Config file found: ./temp_result/hanauma_bay_outdoor/cfg_args
# Creating video for ./temp_result/hanauma_bay_outdoor
# Loading trained model at iteration 30000
# Using cache found in /home/hyunjae/.cache/torch/hub/yvanyin_metric3d_main
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /home/hyunjae/.cache/torch/hub/yvanyin_metric3d_main/mono/model/backbones/ViT_DINO.py:248: FutureWarning: xformers.components is deprecated and is not maintained anymore. It might be removed in a future version of xFormers
#   from xformers.components.attention import ScaledDotProduct
# xFormers not available
# xFormers not available
# Reading camera 46/46
# Loading Training Cameras
# Loading Test Cameras
# Rendering progress: 100%|███████████████████| 1200/1200 [00:28<00:00, 41.57it/s]
# Video saved as ./temp_result/hanauma_bay_outdoor/output_video.mp4

# %%
# !CUDA_VISIBLE_DEVICES=0 python temp_triangle-splatting2/create_ply.py $OUTDOOR_OUTPUR_DIR_PATH/point_cloud/iteration_30000 --out $OUTDOOR_OUTPUR_DIR_PATH/mesh.ply
# Out:
# Saved PLY to: ./temp_result/hanauma_bay_outdoor/mesh.ply
# Vertices: 262488, Faces: 122500

# %% [markdown]
# ### Triangle-Splatting :: Training (Indoor mode)

# %%
DATASET_DIR_PATH
INDOOR_OUTPUR_DIR_PATH = f"./temp_result/{VIDEO_NAME}_indoor"
print(DATASET_DIR_PATH)
print(INDOOR_OUTPUR_DIR_PATH)

# !CUDA_VISIBLE_DEVICES=0 python temp_triangle-splatting2/train.py -s $DATASET_DIR_PATH -m $INDOOR_OUTPUR_DIR_PATH -r $RES --eval  --indoor
# Out:
# ./temp_data/hanauma_bay
# ./temp_result/hanauma_bay_indoor
# Optimizing ./temp_result/hanauma_bay_indoor
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/lpips/weights/v0.1/vgg.pth
# Output folder: ./temp_result/hanauma_bay_indoor [15/10 08:05:30]
# Tensorboard not available: not logging progress [15/10 08:05:30]
# Using cache found in /home/hyunjae/.cache/torch/hub/yvanyin_metric3d_main
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /home/hyunjae/.cache/torch/hub/yvanyin_metric3d_main/mono/model/backbones/ViT_DINO.py:248: FutureWarning: xformers.components is deprecated and is not maintained anymore. It might be removed in a future version of xFormers
#   from xformers.components.attention import ScaledDotProduct
# xFormers not available
# xFormers not available
# Reading camera 46/46 [15/10 08:05:42]
# Loading Training Cameras [15/10 08:05:42]
# Loading Test Cameras [15/10 08:05:43]
# Training progress:   2%|      | 500/30000 [00:11<06:32, 75.09it/s, Loss=0.46321]tensor(0., device='cuda:0') [15/10 08:05:55]
# Training progress:   3%|▏    | 1000/30000 [00:21<06:20, 76.15it/s, Loss=0.43753]
# [ITER 1000] Evaluating test: L1 0.38499101003011066 PSNR 5.78864582379659 SSIM 0.2037340203921 LPIPS 0.6547433833281199 [15/10 08:06:05]
#
# [ITER 1000] Evaluating train: L1 0.40902995467185976 PSNR 5.535048484802246 SSIM 0.18892735093832017 LPIPS 0.660718333721161 [15/10 08:06:05]
# tensor(0., device='cuda:0') [15/10 08:06:05]
# Training progress:   5%|▎    | 1500/30000 [00:30<13:20, 35.58it/s, Loss=0.33045]tensor(0., device='cuda:0') [15/10 08:06:13]
# Training progress:   7%|▎    | 2000/30000 [00:38<07:00, 66.58it/s, Loss=0.24298]
# [ITER 2000] Evaluating test: L1 0.1234168584148089 PSNR 15.608566919962565 SSIM 0.4820924748977025 LPIPS 0.5839717189470927 [15/10 08:06:22]
#
# [ITER 2000] Evaluating train: L1 0.18480214923620225 PSNR 15.065652656555176 SSIM 0.4278267052024603 LPIPS 0.5959555268287658 [15/10 08:06:22]
# tensor(0., device='cuda:0') [15/10 08:06:22]
# Training progress:   8%|▍    | 2500/30000 [00:54<15:21, 29.85it/s, Loss=0.15298]tensor(0., device='cuda:0') [15/10 08:06:37]
# Training progress:  10%|▌    | 3000/30000 [01:01<06:10, 72.80it/s, Loss=0.15159]
# [ITER 3000] Evaluating test: L1 0.09787982453902562 PSNR 16.95948044459025 SSIM 0.5245358248551686 LPIPS 0.5509038766225178 [15/10 08:06:45]
#
# [ITER 3000] Evaluating train: L1 0.17749757319688797 PSNR 16.678217220306397 SSIM 0.4569784763269127 LPIPS 0.567126190662384 [15/10 08:06:45]
# tensor(0., device='cuda:0') [15/10 08:06:45]
# Training progress:  12%|▌    | 3500/30000 [01:08<05:53, 74.94it/s, Loss=0.15207]tensor(0., device='cuda:0') [15/10 08:06:52]
# Training progress:  13%|▋    | 4000/30000 [01:14<04:31, 95.74it/s, Loss=0.13365]
# [ITER 4000] Evaluating test: L1 0.0927127848068873 PSNR 17.345773537953693 SSIM 0.5288303047418594 LPIPS 0.5329800446828206 [15/10 08:06:57]
#
# [ITER 4000] Evaluating train: L1 0.17060879468917847 PSNR 17.50428123474121 SSIM 0.47424374776892364 LPIPS 0.5476607859134675 [15/10 08:06:57]
# Training progress:  80%|███▏| 24000/30000 [13:06<05:36, 17.85it/s, Loss=0.08158]
# [ITER 24000] Evaluating test: L1 0.16557753706971803 PSNR 12.549911260604858 SSIM 0.33657142519950867 LPIPS 0.5377537210782368 [15/10 08:18:50]
#
# [ITER 24000] Evaluating train: L1 0.1516521513462067 PSNR 19.85361909866333 SSIM 0.6367360418313184 LPIPS 0.37421166300773623 [15/10 08:18:50]
# tensor(0., device='cuda:0') [15/10 08:18:50]
# Training progress:  82%|███▎| 24500/30000 [13:48<05:08, 17.82it/s, Loss=0.09085]tensor(0., device='cuda:0') [15/10 08:19:32]
# Training progress:  83%|███▎| 25000/30000 [14:32<04:56, 16.86it/s, Loss=0.17211]
# [ITER 25000] Evaluating test: L1 0.164808119336764 PSNR 12.617305358250935 SSIM 0.34712832421064377 LPIPS 0.5285821855068207 [15/10 08:20:15]
#
# [ITER 25000] Evaluating train: L1 0.1526448342949152 PSNR 19.864635944366455 SSIM 0.6208284681313672 LPIPS 0.3809410244226456 [15/10 08:20:16]
# tensor(0., device='cuda:0') [15/10 08:20:16]
# Training progress:  85%|███▍| 25500/30000 [14:54<03:22, 22.26it/s, Loss=0.07055]tensor(0.6250, device='cuda:0') [15/10 08:20:37]
# Training progress:  87%|███▍| 26000/30000 [15:17<03:06, 21.44it/s, Loss=0.05701]
# [ITER 26000] Evaluating test: L1 0.1676485873758793 PSNR 12.447720289230347 SSIM 0.3399834632873535 LPIPS 0.5290117462476094 [15/10 08:21:01]
#
# [ITER 26000] Evaluating train: L1 0.148567945510149 PSNR 20.393447971343996 SSIM 0.6723789041512647 LPIPS 0.3326550394296646 [15/10 08:21:01]
# tensor(0.6350, device='cuda:0') [15/10 08:21:01]
# Training progress:  88%|███▌| 26500/30000 [15:39<02:25, 24.04it/s, Loss=0.04960]tensor(0.6450, device='cuda:0') [15/10 08:21:22]
# Training progress:  90%|███▌| 27000/30000 [16:00<02:09, 23.08it/s, Loss=0.05374]
# [ITER 27000] Evaluating test: L1 0.16737449914216995 PSNR 12.459445714950562 SSIM 0.34109873324632645 LPIPS 0.5267483095328013 [15/10 08:21:44]
#
# [ITER 27000] Evaluating train: L1 0.14703277722001076 PSNR 20.805421161651612 SSIM 0.6878352826111951 LPIPS 0.3110492587089539 [15/10 08:21:44]
# tensor(0.6550, device='cuda:0') [15/10 08:21:44]
# Training progress:  92%|███▋| 27500/30000 [16:25<02:27, 16.95it/s, Loss=0.14059]tensor(0.6650, device='cuda:0') [15/10 08:22:09]
# Training progress:  93%|███▋| 28000/30000 [16:50<01:28, 22.61it/s, Loss=0.07252]
# [ITER 28000] Evaluating test: L1 0.16767432043949762 PSNR 12.43657334645589 SSIM 0.3394390642642975 LPIPS 0.5272919634977976 [15/10 08:22:34]
#
# [ITER 28000] Evaluating train: L1 0.14646276794373989 PSNR 20.993271350860596 SSIM 0.6946280663483777 LPIPS 0.30351241230964665 [15/10 08:22:34]
# tensor(0.6750, device='cuda:0') [15/10 08:22:34]
# Training progress:  95%|███▊| 28500/30000 [17:15<01:28, 16.87it/s, Loss=0.05513]tensor(0.6850, device='cuda:0') [15/10 08:22:58]
# Training progress:  97%|███▊| 29000/30000 [17:41<00:42, 23.58it/s, Loss=0.05255]
# [ITER 29000] Evaluating test: L1 0.16825563833117485 PSNR 12.407519022623697 SSIM 0.3358334476749102 LPIPS 0.5296249488989512 [15/10 08:23:25]
#
# [ITER 29000] Evaluating train: L1 0.14599568545818328 PSNR 21.11749658584595 SSIM 0.6976702516549267 LPIPS 0.2999936103820801 [15/10 08:23:25]
# tensor(0.6950, device='cuda:0') [15/10 08:23:25]
# Training progress:  98%|███▉| 29500/30000 [18:02<00:20, 24.23it/s, Loss=0.05395]tensor(0.7050, device='cuda:0') [15/10 08:23:46]
# Training progress: 100%|███▉| 29950/30000 [18:21<00:02, 24.58it/s, Loss=0.04265]29960 [15/10 08:24:05]
# Training progress: 100%|████| 30000/30000 [18:23<00:00, 27.19it/s, Loss=0.05951]
#
# [ITER 30000] Evaluating test: L1 0.16866242761413255 PSNR 12.386534770329792 SSIM 0.33259115616480506 LPIPS 0.5312931686639786 [15/10 08:24:06]
#
# [ITER 30000] Evaluating train: L1 0.14586360454559327 PSNR 21.17633790969849 SSIM 0.6971644824021497 LPIPS 0.3024874597787857 [15/10 08:24:07]
# tensor(0., device='cuda:0') [15/10 08:24:07]
# Training is done [15/10 08:24:07]
#
# Training complete. [15/10 08:24:07]

# %% [markdown]
# ### Triangle-Splatting :: Rendering (Indoor mode)

# %%
# !CUDA_VISIBLE_DEVICES=0 python temp_triangle-splatting2/render.py -m $INDOOR_OUTPUR_DIR_PATH
# Out:
# Looking for config file in ./temp_result/hanauma_bay_indoor/cfg_args
# Config file found: ./temp_result/hanauma_bay_indoor/cfg_args
# Rendering ./temp_result/hanauma_bay_indoor
# Loading trained model at iteration 30000 [15/10 08:24:11]
# Using cache found in /home/hyunjae/.cache/torch/hub/yvanyin_metric3d_main
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /home/hyunjae/.cache/torch/hub/yvanyin_metric3d_main/mono/model/backbones/ViT_DINO.py:248: FutureWarning: xformers.components is deprecated and is not maintained anymore. It might be removed in a future version of xFormers
#   from xformers.components.attention import ScaledDotProduct
# xFormers not available
# xFormers not available
# Reading camera 46/46 [15/10 08:24:19]
# Loading Training Cameras [15/10 08:24:19]
# Loading Test Cameras [15/10 08:24:20]
# Rendering progress: 100%|███████████████████████| 40/40 [00:03<00:00, 12.47it/s]
# Rendering progress: 100%|█████████████████████████| 6/6 [00:00<00:00, 15.12it/s]

# %% [markdown]
# ### Triangle-Splatting :: Create a video (Indoor mode)

# %%
# !CUDA_VISIBLE_DEVICES=0 python temp_triangle-splatting2/create_video.py -s $DATASET_DIR_PATH -m $INDOOR_OUTPUR_DIR_PATH -r $RES --save_as $INDOOR_OUTPUR_DIR_PATH/output_video
# Out:
# Looking for config file in ./temp_result/hanauma_bay_indoor/cfg_args
# Config file found: ./temp_result/hanauma_bay_indoor/cfg_args
# Creating video for ./temp_result/hanauma_bay_indoor
# Loading trained model at iteration 30000
# Using cache found in /home/hyunjae/.cache/torch/hub/yvanyin_metric3d_main
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /home/hyunjae/.cache/torch/hub/yvanyin_metric3d_main/mono/model/backbones/ViT_DINO.py:248: FutureWarning: xformers.components is deprecated and is not maintained anymore. It might be removed in a future version of xFormers
#   from xformers.components.attention import ScaledDotProduct
# xFormers not available
# xFormers not available
# Reading camera 46/46
# Loading Training Cameras
# Loading Test Cameras
# Rendering progress: 100%|███████████████████| 1200/1200 [00:23<00:00, 51.42it/s]
# Video saved as ./temp_result/hanauma_bay_indoor/output_video.mp4

# %%
# !CUDA_VISIBLE_DEVICES=0 python temp_triangle-splatting2/create_ply.py $INDOOR_OUTPUR_DIR_PATH/point_cloud/iteration_30000 --out $INDOOR_OUTPUR_DIR_PATH/mesh.ply
# Out:
# Saved PLY to: ./temp_result/hanauma_bay_indoor/mesh.ply
# Vertices: 1367097, Faces: 689935
