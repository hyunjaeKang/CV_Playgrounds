# %% [markdown]
# # triangle-splatting 2
# -----
# - Conda env : [triangle_splatting2](README.md#setup-a-conda-environment)
# -----

# %%
import glob
from pathlib import Path

Path("./output").mkdir(exist_ok=True, parents=True)
mp4_files = glob.glob(pathname="./**/*.mp4", recursive=True)
print(mp4_files)
# Out:
# ['./temp_result/Celebrity_Gym_outdoor/output_video.mp4', './temp_result/waikiki_statue_indoor/output_video.mp4', './temp_result/duke_statue_outdoor/output_video.mp4', './temp_result/Alaska_00_outdoor/output_video.mp4', './temp_result/Celebrity_Gym_indoor/output_video.mp4', './temp_result/WhitePass_Train_indoor/output_video.mp4', './temp_result/hanauma_bay_outdoor/output_video.mp4', './temp_result/WhitePass_Train_outdoor/output_video.mp4', './temp_result/waikiki_statue_outdoor/output_video.mp4', './temp_result/duke_statue_indoor/output_video.mp4', './temp_result/hanauma_bay_indoor/output_video.mp4', './temp_result/Alaska_00_indoor/output_video.mp4']

# %%
import os
for sfp in mp4_files:
    print(f"src file path {sfp}")
    fplst = sfp.split("/")
    ofp = os.path.join("./output", f"{fplst[-2]}_{fplst[-1]}")
    print(f"output file path {ofp}")
    # !ffmpeg -i $sfp -c:v libx264 $ofp
# Out:
# src file path ./temp_result/Celebrity_Gym_outdoor/output_video.mp4
# output file path ./output/Celebrity_Gym_outdoor_output_video.mp4
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...
