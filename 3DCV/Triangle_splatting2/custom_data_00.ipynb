# %% [markdown]
# # triangle-splatting 2 :: Custom data :: waikiki_statue
#
# -----
# - Conda env : [triangle_splatting2](README.md#setup-a-conda-environment)
# -----

# %% [markdown]
# ### Check system

# %%
# !nvidia-smi
# Out:
# Wed Oct 15 15:29:12 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 575.57.08              Driver Version: 575.57.08      CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 2080 Ti     On  |   00000000:01:00.0  On |                  N/A |
# | 22%   42C    P8             32W /  250W |     533MiB /  11264MiB |     37%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2079      G   /usr/lib/xorg/Xorg                      278MiB |
# |    0   N/A  N/A            2259      G   /usr/bin/gnome-shell                     36MiB |
# |    0   N/A  N/A            3654      G   /usr/share/code/code                    160MiB |
# |    0   N/A  N/A            3715      G   ...ersion=20251014-170058.618000         43MiB |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### Download a video

# %%
import os
from pathlib import Path

Path("./temp_data").mkdir(exist_ok=True, parents=True)

# %%
import gdown
VIDEO_NAME = "waikiki_statue"

FPS = 10
RES = 4
id = "1v_r7gjiomJNwemsXKaaJNpcTCFKl-Nbj"
vid_path = f"./temp_data/{VIDEO_NAME}.mov"

if not os.path.exists(vid_path):
    gdown.download(id=id, output = vid_path)
else:
    print(f"{vid_path} already is downloaded")
# Out:
# ./temp_data/waikiki_statue.mov already is downloaded

# %% [markdown]
# ### Extract images from the video

# %%
DATASET_DIR_PATH = f"./temp_data/{VIDEO_NAME}"
IMAGES_DIR_PATH = os.path.join(DATASET_DIR_PATH, "images")
DATABASE_PATH = os.path.join(DATASET_DIR_PATH, "database.db")

if not os.path.exists(IMAGES_DIR_PATH):
    Path(IMAGES_DIR_PATH).mkdir(exist_ok=True, parents=True)
    # !ffmpeg -i $vid_path -vf fps=$FPS $IMAGES_DIR_PATH/frame_%04d.jpg
else:
    print(f"{IMAGES_DIR_PATH} already is extracted")
# Out:
# ./temp_data/waikiki_statue/images already is extracted

# %% [markdown]
# ### Colmap :: Feature Extraction & Matching & Reconstruction

# %%
SPARSE_DIR = os.path.join(DATASET_DIR_PATH, "sparse")
Path(SPARSE_DIR).mkdir(exist_ok=True, parents=True)

if not os.path.exists(DATABASE_PATH):
    # Colmap Feature Extraction
    # !colmap feature_extractor \
        --database_path $DATABASE_PATH \
        --image_path $IMAGES_DIR_PATH  --ImageReader.camera_model PINHOLE
    # !colmap sequential_matcher \
        --database_path $DATABASE_PATH
    # !colmap mapper \
        --database_path $DATABASE_PATH \
        --image_path $IMAGES_DIR_PATH \
        --output_path $SPARSE_DIR
else:
    print(f"{DATABASE_PATH} already is extracted and reconstructed")
# Out:
# ./temp_data/waikiki_statue/database.db already is extracted and reconstructed

# %% [markdown]
# ### Triangle-Splatting :: Training (Outdoor mode)

# %%
DATASET_DIR_PATH
OUTDOOR_OUTPUR_DIR_PATH = f"./temp_result/{VIDEO_NAME}_outdoor"
print(DATASET_DIR_PATH)
print(OUTDOOR_OUTPUR_DIR_PATH)

# !CUDA_VISIBLE_DEVICES=0 python temp_triangle-splatting2/train.py -s $DATASET_DIR_PATH -m $OUTDOOR_OUTPUR_DIR_PATH -r $RES --eval
# Out:
# ./temp_data/waikiki_statue
# ./temp_result/waikiki_statue_outdoor
# Optimizing ./temp_result/waikiki_statue_outdoor
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/lpips/weights/v0.1/vgg.pth
# Output folder: ./temp_result/waikiki_statue_outdoor [15/10 05:53:06]
# Tensorboard not available: not logging progress [15/10 05:53:06]
# Using cache found in /home/hyunjae/.cache/torch/hub/yvanyin_metric3d_main
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /home/hyunjae/.cache/torch/hub/yvanyin_metric3d_main/mono/model/backbones/ViT_DINO.py:248: FutureWarning: xformers.components is deprecated and is not maintained anymore. It might be removed in a future version of xFormers
#   from xformers.components.attention import ScaledDotProduct
# xFormers not available
# xFormers not available
# Reading camera 375/
# Training progress:  98%|███▉| 29500/30000 [13:42<00:09, 53.23it/s, Loss=0.10173]tensor(0.7050, device='cuda:0') [15/10 06:27:00]
# Training progress:  99%|███▉| 29670/30000 [13:45<00:06, 52.29it/s, Loss=0.09982]29672 [15/10 06:27:04]
# Training progress: 100%|████| 30000/30000 [13:51<00:00, 36.07it/s, Loss=0.10470]
#
# [ITER 30000] Evaluating test: L1 0.05550113708731976 PSNR 19.633157486611225 SSIM 0.709244134578299 LPIPS 0.29476573556027513 [15/10 06:27:11]
#
# [ITER 30000] Evaluating train: L1 0.050193119794130325 PSNR 20.340447235107423 SSIM 0.7388174057006837 LPIPS 0.2772775411605835 [15/10 06:27:11]
# tensor(0., device='cuda:0') [15/10 06:27:11]
# Training is done [15/10 06:27:12]
#
# Training complete. [15/10 06:27:13]

# %% [markdown]
# ### Triangle-Splatting :: Rendering (Outdoor mode)

# %%
# !CUDA_VISIBLE_DEVICES=0 python temp_triangle-splatting2/render.py -m $OUTDOOR_OUTPUR_DIR_PATH -r $RES -s $DATASET_DIR_PATH
# Out:
# Looking for config file in ./temp_result/waikiki_statue_outdoor/cfg_args
# Config file found: ./temp_result/waikiki_statue_outdoor/cfg_args
# Rendering ./temp_result/waikiki_statue_outdoor
# Loading trained model at iteration 30000 [15/10 06:27:33]
# Using cache found in /home/hyunjae/.cache/torch/hub/yvanyin_metric3d_main
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /home/hyunjae/.cache/torch/hub/yvanyin_metric3d_main/mono/model/backbones/ViT_DINO.py:248: FutureWarning: xformers.components is deprecated and is not maintained anymore. It might be removed in a future version of xFormers
#   from xformers.components.attention import ScaledDotProduct
# xFormers not available
# xFormers not available
# Reading camera 375/375 [15/10 06:28:02]
# Loading Training Cameras [15/10 06:28:02]
# Loading Test Cameras [15/10 06:28:09]
# Rendering progress: 100%|█████████████████████| 328/328 [00:24<00:00, 13.48it/s]
# Rendering progress: 100%|███████████████████████| 47/47 [00:03<00:00, 13.95it/s]

# %% [markdown]
# ### Triangle-Splatting :: Create a video (Outdoor mode)

# %%
# !CUDA_VISIBLE_DEVICES=0 python temp_triangle-splatting2/create_video.py  -s $DATASET_DIR_PATH -m $OUTDOOR_OUTPUR_DIR_PATH -r $RES --save_as $OUTDOOR_OUTPUR_DIR_PATH/output_video
# Out:
# Looking for config file in ./temp_result/waikiki_statue_outdoor/cfg_args
# Config file found: ./temp_result/waikiki_statue_outdoor/cfg_args
# Creating video for ./temp_result/waikiki_statue_outdoor
# Loading trained model at iteration 30000
# Using cache found in /home/hyunjae/.cache/torch/hub/yvanyin_metric3d_main
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /home/hyunjae/.cache/torch/hub/yvanyin_metric3d_main/mono/model/backbones/ViT_DINO.py:248: FutureWarning: xformers.components is deprecated and is not maintained anymore. It might be removed in a future version of xFormers
#   from xformers.components.attention import ScaledDotProduct
# xFormers not available
# xFormers not available
# Reading camera 375/375
# Loading Training Cameras
# Loading Test Cameras
# Rendering progress: 100%|███████████████████| 1200/1200 [00:56<00:00, 21.33it/s]
# Video saved as ./temp_result/waikiki_statue_outdoor/output_video.mp4

# %%
# !CUDA_VISIBLE_DEVICES=0 python temp_triangle-splatting2/create_ply.py $OUTDOOR_OUTPUR_DIR_PATH/point_cloud/iteration_30000 --out $OUTDOOR_OUTPUR_DIR_PATH/mesh.ply
# Out:
# Saved PLY to: ./temp_result/waikiki_statue_outdoor/mesh.ply
# Vertices: 331624, Faces: 160423

# %% [markdown]
# ### Triangle-Splatting :: Training (Indoor mode)

# %%
DATASET_DIR_PATH
INDOOR_OUTPUR_DIR_PATH = f"./temp_result/{VIDEO_NAME}_indoor"
print(DATASET_DIR_PATH)
print(INDOOR_OUTPUR_DIR_PATH)

# !CUDA_VISIBLE_DEVICES=0 python temp_triangle-splatting2/train.py -s $DATASET_DIR_PATH -m $INDOOR_OUTPUR_DIR_PATH -r $RES --eval  --indoor
# Out:
# ./temp_data/waikiki_statue
# ./temp_result/waikiki_statue_indoor
# Optimizing ./temp_result/waikiki_statue_indoor
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/lpips/weights/v0.1/vgg.pth
# Output folder: ./temp_result/waikiki_statue_indoor [15/10 06:28:51]
# Tensorboard not available: not logging progress [15/10 06:28:51]
# Using cache found in /home/hyunjae/.cache/torch/hub/yvanyin_metric3d_main
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /home/hyunjae/.cache/torch/hub/yvanyin_metric3d_main/mono/model/backbones/ViT_DINO.py:248: FutureWarning: xformers.components is deprecated and is not maintained anymore. It might be removed in a future version of xFormers
#   from xformers.components.attention import ScaledDotProduct
# xFormers not available
# xFormers not available
# Reading camera 375/
#
# [ITER 25000] Evaluating train: L1 0.2127990484237671 PSNR 9.308057308197021 SSIM 0.39028571844100957 LPIPS 0.5025237679481507 [15/10 06:42:13]
# tensor(0., device='cuda:0') [15/10 06:42:13]
# Training progress:  85%|███▍| 25500/30000 [13:00<01:38, 45.54it/s, Loss=0.30538]tensor(0.6251, device='cuda:0') [15/10 06:42:23]
# Training progress:  87%|███▍| 26000/30000 [13:11<01:27, 45.70it/s, Loss=0.30884]
# [ITER 26000] Evaluating test: L1 0.21228688765079418 PSNR 9.396641021079205 SSIM 0.375477579045803 LPIPS 0.5132589004141219 [15/10 06:42:36]
#
# [ITER 26000] Evaluating train: L1 0.2120667487382889 PSNR 9.239156913757325 SSIM 0.4102339029312134 LPIPS 0.49227445721626284 [15/10 06:42:36]
# tensor(0.6362, device='cuda:0') [15/10 06:42:36]
# Training progress:  88%|███▌| 26500/30000 [13:24<01:27, 39.95it/s, Loss=0.29810]tensor(0.6455, device='cuda:0') [15/10 06:42:47]
# Training progress:  90%|███▌| 27000/30000 [13:37<01:14, 40.07it/s, Loss=0.27301]
# [ITER 27000] Evaluating test: L1 0.2069140019568991 PSNR 9.524346513951079 SSIM 0.3935450873476394 LPIPS 0.4997701492715389 [15/10 06:43:01]
#
# [ITER 27000] Evaluating train: L1 0.2065822869539261 PSNR 9.362343978881837 SSIM 0.4278823256492615 LPIPS 0.4771260797977448 [15/10 06:43:01]
# tensor(0.6553, device='cuda:0') [15/10 06:43:01]
# Training progress:  92%|███▋| 27500/30000 [13:49<00:54, 46.23it/s, Loss=0.29455]tensor(0.6653, device='cuda:0') [15/10 06:43:12]
# Training progress:  93%|███▋| 28000/30000 [14:00<00:43, 46.13it/s, Loss=0.31180]
# [ITER 28000] Evaluating test: L1 0.20328539070930887 PSNR 9.612629717968879 SSIM 0.40414082560133424 LPIPS 0.49197704804704545 [15/10 06:43:24]
#
# [ITER 28000] Evaluating train: L1 0.20299994051456452 PSNR 9.450183963775634 SSIM 0.44025480151176455 LPIPS 0.46886054873466493 [15/10 06:43:24]
# tensor(0.6751, device='cuda:0') [15/10 06:43:24]
# Training progress:  95%|███▊| 28500/30000 [14:12<00:32, 46.72it/s, Loss=0.28708]tensor(0.6851, device='cuda:0') [15/10 06:43:35]
# Training progress:  97%|███▊| 29000/30000 [14:23<00:21, 46.36it/s, Loss=0.31215]
# [ITER 29000] Evaluating test: L1 0.200964019019553 PSNR 9.671117194155428 SSIM 0.41088295807229713 LPIPS 0.4867278064819092 [15/10 06:43:47]
#
# [ITER 29000] Evaluating train: L1 0.2003689080476761 PSNR 9.504209518432617 SSIM 0.448464572429657 LPIPS 0.4627108097076416 [15/10 06:43:47]
# tensor(0.6950, device='cuda:0') [15/10 06:43:47]
# Training progress:  98%|███▉| 29500/30000 [14:35<00:10, 47.45it/s, Loss=0.27458]tensor(0.7051, device='cuda:0') [15/10 06:43:58]
# Training progress:  99%|███▉| 29670/30000 [14:39<00:08, 37.81it/s, Loss=0.26134]29672 [15/10 06:44:02]
# Training progress: 100%|████| 30000/30000 [14:49<00:00, 33.72it/s, Loss=0.28726]
#
# [ITER 30000] Evaluating test: L1 0.19973780151377332 PSNR 9.703754110539213 SSIM 0.41404766351618666 LPIPS 0.48480232408706175 [15/10 06:44:13]
#
# [ITER 30000] Evaluating train: L1 0.19954358339309694 PSNR 9.53399600982666 SSIM 0.44995676279068 LPIPS 0.4619229912757874 [15/10 06:44:14]
# tensor(0., device='cuda:0') [15/10 06:44:14]
# Training is done [15/10 06:44:15]
#
# Training complete. [15/10 06:44:15]

# %% [markdown]
# ### Triangle-Splatting :: Rendering (Indoor mode)

# %%
# !CUDA_VISIBLE_DEVICES=0 python temp_triangle-splatting2/render.py -m $INDOOR_OUTPUR_DIR_PATH
# Out:
# Looking for config file in ./temp_result/waikiki_statue_indoor/cfg_args
# Config file found: ./temp_result/waikiki_statue_indoor/cfg_args
# Rendering ./temp_result/waikiki_statue_indoor
# Loading trained model at iteration 30000 [15/10 06:44:19]
# Using cache found in /home/hyunjae/.cache/torch/hub/yvanyin_metric3d_main
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /home/hyunjae/.cache/torch/hub/yvanyin_metric3d_main/mono/model/backbones/ViT_DINO.py:248: FutureWarning: xformers.components is deprecated and is not maintained anymore. It might be removed in a future version of xFormers
#   from xformers.components.attention import ScaledDotProduct
# xFormers not available
# xFormers not available
# Reading camera 375/375 [15/10 06:44:41]
# Loading Training Cameras [15/10 06:44:41]
# Loading Test Cameras [15/10 06:44:48]
# Rendering progress: 100%|█████████████████████| 328/328 [00:20<00:00, 16.10it/s]
# Rendering progress: 100%|███████████████████████| 47/47 [00:02<00:00, 16.23it/s]

# %% [markdown]
# ### Triangle-Splatting :: Create a video (Indoor mode)

# %%
# !CUDA_VISIBLE_DEVICES=0 python temp_triangle-splatting2/create_video.py -s $DATASET_DIR_PATH -m $INDOOR_OUTPUR_DIR_PATH -r $RES --save_as $INDOOR_OUTPUR_DIR_PATH/output_video
# Out:
# Looking for config file in ./temp_result/waikiki_statue_indoor/cfg_args
# Config file found: ./temp_result/waikiki_statue_indoor/cfg_args
# Creating video for ./temp_result/waikiki_statue_indoor
# Loading trained model at iteration 30000
# Using cache found in /home/hyunjae/.cache/torch/hub/yvanyin_metric3d_main
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /home/hyunjae/anaconda3/envs/triangle_splatting2/lib/python3.11/site-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /home/hyunjae/.cache/torch/hub/yvanyin_metric3d_main/mono/model/backbones/ViT_DINO.py:248: FutureWarning: xformers.components is deprecated and is not maintained anymore. It might be removed in a future version of xFormers
#   from xformers.components.attention import ScaledDotProduct
# xFormers not available
# xFormers not available
# Reading camera 375/375
# Loading Training Cameras
# Loading Test Cameras
# Rendering progress: 100%|███████████████████| 1200/1200 [00:31<00:00, 38.39it/s]
# Video saved as ./temp_result/waikiki_statue_indoor/output_video.mp4

# %%
# !CUDA_VISIBLE_DEVICES=0 python temp_triangle-splatting2/create_ply.py --help
# Out:
# usage: create_ply.py [-h] [--out OUT] [--camera CAMERA] [--degree DEGREE]
#                      [--cpu] [--zup]
#                      scene_dir
#
# Export triangle scene to PLY with per-vertex colors.
#
# positional arguments:
#   scene_dir        Directory containing point_cloud_state_dict.pt
#
# options:
#   -h, --help       show this help message and exit
#   --out OUT        Output path, default <scene_dir>/mesh.ply
#   --camera CAMERA  Camera center x,y,z
#   --degree DEGREE  Override SH degree to evaluate
#   --cpu            Force CPU for loading and SH eval
#   --zup            Input is Z-up, rotate to Y-up for standard viewers

# %%
# !CUDA_VISIBLE_DEVICES=0 python temp_triangle-splatting2/create_ply.py $INDOOR_OUTPUR_DIR_PATH/point_cloud/iteration_30000 --out $INDOOR_OUTPUR_DIR_PATH/mesh.ply
# Out:
# Saved PLY to: ./temp_result/waikiki_statue_indoor/mesh.ply
# Vertices: 516476, Faces: 290066
