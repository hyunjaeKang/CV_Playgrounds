# %% [markdown]
# # gsplat :: Fit a single image
#
# ----
#
# Conda env : [gsplat](./README.md#setup-a-conda-environment)
#
# ----

# %%
# !python ./utils/test_image_fitting.py --height 256 --width 256 --save_imgs --output-dir="./output/"

# %%
from IPython.display import Video

Video("./output/training_100000_1000_3dgs.mp4")
# Out:
# <video src="./output/training_100000_1000_3dgs.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# !python ./utils/test_image_fitting.py --img-path=./data/sunset.jpeg --save_imgs --output-dir="./output/"

# %%
from IPython.display import Video

Video("./output/sunset_100000_1000_3dgs.mp4")
# Out:
# <video src="./output/sunset_100000_1000_3dgs.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# !python ./utils/test_image_fitting.py --img-path=./data/sunset.jpeg --save_imgs --output-dir="./output/" --iterations=100000

# %%
from IPython.display import Video

Video("./output/sunset_100000_100000_3dgs.mp4")
# Out:
# <video src="./output/sunset_100000_100000_3dgs.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# !python ./utils/test_image_fitting.py --img-path=./data/swim_pool.jpeg --save_imgs --output-dir="./output/"

# %%
from IPython.display import Video

Video("./output/swim_pool_100000_1000_3dgs.mp4")
# Out:
# <video src="./output/swim_pool_100000_1000_3dgs.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# !python ./utils/test_image_fitting.py --img-path=./data/swim_pool.jpeg --save_imgs --output-dir="./output/" --iterations=100000

# %%
from IPython.display import Video

Video("./output/swim_pool_100000_100000_3dgs.mp4")
# Out:
# <video src="./output/swim_pool_100000_100000_3dgs.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
