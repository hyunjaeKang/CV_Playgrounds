# %% [markdown]
# # SFA3D: Run demo_front
#
# Demonstration script for the front view only
#
# ---
#
# - Conda env : [3dcv_playgrounds](../README.md#setup-a-conda-environment)
#
# ----
#
# - Ref:
#     - https://github.com/hyunjaeKang/SFA3D
#     - https://learnopencv.com/3d-lidar-object-detection/

# %%
# !nvidia-smi
# Out:
# Fri Oct 17 17:39:01 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 575.57.08              Driver Version: 575.57.08      CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 2080 Ti     On  |   00000000:01:00.0  On |                  N/A |
# | 31%   44C    P8             32W /  250W |     515MiB /  11264MiB |     35%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2130      G   /usr/lib/xorg/Xorg                      280MiB |
# |    0   N/A  N/A            2310      G   /usr/bin/gnome-shell                     34MiB |
# |    0   N/A  N/A            3501      G   /usr/share/code/code                    120MiB |
# |    0   N/A  N/A            4259      G   ...ersion=20251017-090200.149000         66MiB |
# +-----------------------------------------------------------------------------------------+

# %%
import os
pre_dir = os.getcwd()
os.chdir('./temp_SFA3D/sfa')
wk_dir = os.getcwd()
print(pre_dir)
print(wk_dir)
# Out:
# /home/hyunjae/110_HyunJae_Git/2025_Playgrounds/CV_Playgrounds/3DCV/SFA3D
# /home/hyunjae/110_HyunJae_Git/2025_Playgrounds/CV_Playgrounds/3DCV/SFA3D/temp_SFA3D/sfa

# %%
# !python demo_front.py
# Out:
# Downloading data for demonstration...
# 100% [................................................] 1261710548 / 1261710548
# Unzipping the downloaded data...
# using ResNet architecture with feature pyramid
#
#
# -*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=
#
#
# Loaded weights from ../checkpoints/fpn_resnet_18/fpn_resnet_18_epoch_300.pth
#
# Create video writer at ../results/fpn_resnet_18/2011_09_26_drive_0014_sync_front.avi

# %%
from pathlib import Path

output_dir = os.path.join(pre_dir, "output")
Path(output_dir).mkdir(exist_ok=True, parents=True)
full_out_video_path = os.path.join(output_dir, "temp_full_2011_09_26_drive_0014_sync_front.mp4")
half_out_video_path = os.path.join(output_dir, "half_2011_09_26_drive_0014_sync_front.mp4")
src_video_path = os.path.join(wk_dir, "../results/fpn_resnet_18/2011_09_26_drive_0014_sync_front.avi")
src_video_path = os.path.abspath(src_video_path)

print(src_video_path)
print(full_out_video_path)
print(half_out_video_path)

# !ffmpeg -i $src_video_path $full_out_video_path
# !ffmpeg -i $src_video_path -vf scale=304:394 $half_out_video_path
# Out:
# /home/hyunjae/110_HyunJae_Git/2025_Playgrounds/CV_Playgrounds/3DCV/SFA3D/temp_SFA3D/results/fpn_resnet_18/2011_09_26_drive_0014_sync_front.avi
# /home/hyunjae/110_HyunJae_Git/2025_Playgrounds/CV_Playgrounds/3DCV/SFA3D/output/temp_full_2011_09_26_drive_0014_sync_front.mp4
# /home/hyunjae/110_HyunJae_Git/2025_Playgrounds/CV_Playgrounds/3DCV/SFA3D/output/half_2011_09_26_drive_0014_sync_front.mp4
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, avi, from '/home/hyunjae/110_HyunJae_Git/2025_Playgrounds/CV_Playgrounds/3DCV/SFA3D/temp_SFA3D/results/fpn_resnet_18/2011_09_26_drive_0014_sync_front.avi':
#   Metadata:
#     software        : Lavf59.27.100
#   Duration: 00:00:10.47, start: 0.000000, bitrate: 24840 kb/s
#   Stream #0:0: Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj420p(pc, bt470bg/unknown/unknown), 608x790, 24908 kb/s, 30 fps, 30 tbr, 30 tbn, 30 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5fd1a3c74400] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5fd1a3c74400] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x5fd1a3c74400] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=24 lookahead_threads=4 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/hyunjae/110_HyunJae_Git/2025_Playgrounds/CV_Playgrounds/3DCV/SFA3D/output/temp_full_2011_09_26_drive_0014_sync_front.mp4':
#   Metadata:
#     software        : Lavf59.27.100
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuvj420p(pc, bt470bg/unknown/unknown, progressive), 608x790, q=2-31, 30 fps, 15360 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  314 fps=227 q=-1.0 Lsize=    9213kB time=00:00:10.36 bitrate=7280.5kbits/s speed= 7.5x
# video:9209kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.050522%
# [libx264 @ 0x5fd1a3c74400] frame I:2     Avg QP:25.30  size: 57346
# [libx264 @ 0x5fd1a3c74400] frame P:79    Avg QP:28.57  size: 38084
# [libx264 @ 0x5fd1a3c74400] frame B:233   Avg QP:30.16  size: 27062
# [libx264 @ 0x5fd1a3c74400] consecutive B-frames:  1.0%  0.0%  1.0% 98.1%
# [libx264 @ 0x5fd1a3c74400] mb I  I16..4:  6.4% 61.5% 32.2%
# [libx264 @ 0x5fd1a3c74400] mb P  I16..4:  6.9% 23.3% 22.5%  P16..4: 11.5%  8.9%  6.9%  0.0%  0.0%    skip:20.0%
# [libx264 @ 0x5fd1a3c74400] mb B  I16..4:  4.9%  5.9%  7.8%  B16..8: 29.7% 17.3%  9.2%  direct: 4.4%  skip:20.9%  L0:45.7% L1:40.5% BI:13.8%
# [libx264 @ 0x5fd1a3c74400] 8x8 transform intra:38.4% inter:25.4%
# [libx264 @ 0x5fd1a3c74400] coded y,uvDC,uvAC intra: 64.8% 49.1% 31.4% inter: 29.9% 14.1% 4.4%
# [libx264 @ 0x5fd1a3c74400] i16 v,h,dc,p: 39% 26% 21% 14%
# [libx264 @ 0x5fd1a3c74400] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 22% 41%  3%  2%  2%  4%  2%  6%
# [libx264 @ 0x5fd1a3c74400] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 19% 28%  5%  5%  5%  5%  4%  5%
# [libx264 @ 0x5fd1a3c74400] i8c dc,h,v,p: 67% 17% 14%  2%
# [libx264 @ 0x5fd1a3c74400] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5fd1a3c74400] ref P L0: 39.0% 20.6% 25.1% 15.3%
# [libx264 @ 0x5fd1a3c74400] ref B L0: 81.3% 14.2%  4.5%
# [libx264 @ 0x5fd1a3c74400] ref B L1: 92.1%  7.9%
# [libx264 @ 0x5fd1a3c74400] kb/s:7206.78
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, avi, from '/home/hyunjae/110_HyunJae_Git/2025_Playgrounds/CV_Playgrounds/3DCV/SFA3D/temp_SFA3D/results/fpn_resnet_18/2011_09_26_drive_0014_sync_front.avi':
#   Metadata:
#     software        : Lavf59.27.100
#   Duration: 00:00:10.47, start: 0.000000, bitrate: 24840 kb/s
#   Stream #0:0: Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj420p(pc, bt470bg/unknown/unknown), 608x790, 24908 kb/s, 30 fps, 30 tbr, 30 tbn, 30 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5677602cb200] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x56776025a400] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x56776025a400] profile High, level 2.1, 4:2:0, 8-bit
# [libx264 @ 0x56776025a400] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/hyunjae/110_HyunJae_Git/2025_Playgrounds/CV_Playgrounds/3DCV/SFA3D/output/half_2011_09_26_drive_0014_sync_front.mp4':
#   Metadata:
#     software        : Lavf59.27.100
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuvj420p(pc, bt470bg/unknown/unknown, progressive), 304x394, q=2-31, 30 fps, 15360 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  314 fps=292 q=-1.0 Lsize=    1747kB time=00:00:10.36 bitrate=1380.3kbits/s speed=9.65x
# video:1742kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.259804%
# [libx264 @ 0x56776025a400] frame I:2     Avg QP:25.32  size: 15686
# [libx264 @ 0x56776025a400] frame P:79    Avg QP:27.59  size:  8599
# [libx264 @ 0x56776025a400] frame B:233   Avg QP:29.41  size:  4604
# [libx264 @ 0x56776025a400] consecutive B-frames:  1.0%  0.0%  1.0% 98.1%
# [libx264 @ 0x56776025a400] mb I  I16..4:  9.8% 29.3% 60.9%
# [libx264 @ 0x56776025a400] mb P  I16..4:  4.6% 13.1% 20.2%  P16..4: 19.9% 17.5% 12.4%  0.0%  0.0%    skip:12.3%
# [libx264 @ 0x56776025a400] mb B  I16..4:  1.2%  2.0%  2.9%  B16..8: 36.5% 23.6% 10.5%  direct: 6.4%  skip:16.7%  L0:44.7% L1:40.7% BI:14.5%
# [libx264 @ 0x56776025a400] 8x8 transform intra:33.8% inter:32.1%
# [libx264 @ 0x56776025a400] coded y,uvDC,uvAC intra: 64.5% 46.7% 32.5% inter: 32.5% 13.6% 5.1%
# [libx264 @ 0x56776025a400] i16 v,h,dc,p: 48% 36% 10%  6%
# [libx264 @ 0x56776025a400] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17% 19% 43%  3%  3%  2%  5%  2%  6%
# [libx264 @ 0x56776025a400] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 21% 23%  5%  6%  5%  6%  4%  6%
# [libx264 @ 0x56776025a400] i8c dc,h,v,p: 68% 17% 14%  1%
# [libx264 @ 0x56776025a400] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x56776025a400] ref P L0: 38.2% 25.8% 21.3% 14.7%
# [libx264 @ 0x56776025a400] ref B L0: 85.5% 10.7%  3.8%
# [libx264 @ 0x56776025a400] ref B L1: 94.6%  5.4%
# [libx264 @ 0x56776025a400] kb/s:1363.07

# %%
from IPython.display import Video

# For a local video file
Video(full_out_video_path)
# Out:
# <video src="/home/hyunjae/110_HyunJae_Git/2025_Playgrounds/CV_Playgrounds/3DCV/SFA3D/output/temp_full_2011_09_26_drive_0014_sync_front.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# For a local video file
Video(half_out_video_path)
# Out:
# <video src="/home/hyunjae/110_HyunJae_Git/2025_Playgrounds/CV_Playgrounds/3DCV/SFA3D/output/half_2011_09_26_drive_0014_sync_front.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
