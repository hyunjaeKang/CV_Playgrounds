# %% [markdown]
# # SFA3D: Run demo_2_sides
#
# Demonstration script for both front view and back view
#
# ---
#
# - Conda env : [3dcv_playgrounds](../README.md#setup-a-conda-environment)
#
# ----
#
# - Ref:
#     - https://github.com/hyunjaeKang/SFA3D
#     - https://learnopencv.com/3d-lidar-object-detection/

# %%
# !nvidia-smi
# Out:
# Fri Oct 17 17:38:42 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 575.57.08              Driver Version: 575.57.08      CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 2080 Ti     On  |   00000000:01:00.0  On |                  N/A |
# | 32%   45C    P8             32W /  250W |     578MiB /  11264MiB |     35%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import os
pre_dir = os.getcwd()
os.chdir('./temp_SFA3D/sfa')
wk_dir = os.getcwd()
print(pre_dir)
print(wk_dir)
# Out:
# /home/hyunjae/110_HyunJae_Git/2025_Playgrounds/CV_Playgrounds/3DCV/SFA3D
# /home/hyunjae/110_HyunJae_Git/2025_Playgrounds/CV_Playgrounds/3DCV/SFA3D/temp_SFA3D/sfa

# %%
# !python demo_2_sides.py --gpu_idx 0 --peak_thresh 0.2
# Out:
# The dataset have been downloaded
# using ResNet architecture with feature pyramid
#
#
# -*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=
#
#
# Loaded weights from ../checkpoints/fpn_resnet_18/fpn_resnet_18_epoch_300.pth
#
# Create video writer at ../results/fpn_resnet_18/2011_09_26_drive_0014_sync_both_2_sides.avi

# %%
from pathlib import Path

output_dir = os.path.join(pre_dir, "output")
Path(output_dir).mkdir(exist_ok=True, parents=True)
full_out_video_path = os.path.join(output_dir, "temp_full_2011_09_26_drive_0014_sync_both_2_sides.avi.mp4")
half_out_video_path = os.path.join(output_dir, "half_2011_09_26_drive_0014_sync_both_2_sides.avi.mp4")
src_video_path = os.path.join(wk_dir, "../results/fpn_resnet_18/2011_09_26_drive_0014_sync_both_2_sides.avi")
src_video_path = os.path.abspath(src_video_path)

print(src_video_path)
print(full_out_video_path)
print(half_out_video_path)

# !ffmpeg -i $src_video_path $full_out_video_path
# !ffmpeg -i $src_video_path -vf scale=304:394 $half_out_video_path
# Out:
# /home/hyunjae/110_HyunJae_Git/2025_Playgrounds/CV_Playgrounds/3DCV/SFA3D/temp_SFA3D/results/fpn_resnet_18/2011_09_26_drive_0014_sync_both_2_sides.avi
# /home/hyunjae/110_HyunJae_Git/2025_Playgrounds/CV_Playgrounds/3DCV/SFA3D/output/temp_full_2011_09_26_drive_0014_sync_both_2_sides.avi.mp4
# /home/hyunjae/110_HyunJae_Git/2025_Playgrounds/CV_Playgrounds/3DCV/SFA3D/output/half_2011_09_26_drive_0014_sync_both_2_sides.avi.mp4
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
from IPython.display import Video

# For a local video file
Video(full_out_video_path)
# Out:
# <video src="/home/hyunjae/110_HyunJae_Git/2025_Playgrounds/CV_Playgrounds/3DCV/SFA3D/output/temp_full_2011_09_26_drive_0014_sync_both_2_sides.avi.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# For a local video file
Video(half_out_video_path)
# Out:
# <video src="/home/hyunjae/110_HyunJae_Git/2025_Playgrounds/CV_Playgrounds/3DCV/SFA3D/output/half_2011_09_26_drive_0014_sync_both_2_sides.avi.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
