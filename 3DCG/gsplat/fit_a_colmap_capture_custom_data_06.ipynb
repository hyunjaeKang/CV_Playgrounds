# %% [markdown]
# # gsplat :: Custom data :: WhitePass_Train
#
# - Conda env : [gsplat](README.md#setup-a-conda-environment)

# %%
# !nvidia-smi
# Out:
# Mon Sep 29 14:21:11 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 575.57.08              Driver Version: 575.57.08      CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 2080 Ti     On  |   00000000:01:00.0  On |                  N/A |
# | 26%   46C    P5             35W /  250W |    2354MiB /  11264MiB |     29%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# ## Download data

# %%
import gdown

id = "1LdXaVkme3egIwiMMevApDnwZcMUv0VvK"
vid_path = "./temp_data/WhitePass_Train.mov"

gdown.download(id=id, output = vid_path)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1LdXaVkme3egIwiMMevApDnwZcMUv0VvK
# To: /home/hyunjae/110_HyunJae_Git/2025_Playgrounds/CV_Playgrounds/3DCG/gsplat/temp_data/WhitePass_Train.mov
# 100%|██████████| 60.7M/60.7M [00:09<00:00, 6.24MB/s]
# './temp_data/WhitePass_Train.mov'

# %%
# !python ./utils/video2imgs.py --video_path "./temp_data/WhitePass_Train.mov" --output_dir "./temp_data/WhitePass_Train_seq/images" --fps 10 --img_rotate 1
# Out:
# Saved 554 frames at 10.0 fps to './temp_data/WhitePass_Train_seq/images'.

# %%
# !python ./utils/imgs2poses.py --data_dir "./temp_data/WhitePass_Train_seq" --factor 4 --match_type sequential_matcher
# Out:
# Need to run COLMAP
# Features extracted
# Features matched
# Sparse map created
# Finished running COLMAP, see ./temp_data/WhitePass_Train_seq/colmap_output.txt for logs
# Post-colmap
# Cameras 5
# Images # 550
# Points (183536, 3) Visibility (183536, 550)
# Depth stats 0.015136922914010349 24.7725382427448 1.452517412584312
# Factors: [4]
# Minifying 4 ./temp_data/WhitePass_Train_seq
# mogrify -resize 25% -format png *.jpg
# Removed duplicates
# Done
# Done with imgs2poses

# %% [markdown]
# ## 3DGS Default mode

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_trainer.py default \
    --data_dir ./temp_data/WhitePass_Train_seq/ --data_factor 4\
    --result_dir ./temp_results/WhitePass_Train_seq_default_factor_4 --save_ply --disable_viewer
# Out:
# [Parser] 550 images, taken by 1 cameras.
# ...
# Scene scale: 2.2040180200210973
# Model initialized. Number of GS: 183536
# loss=0.142| sh degree=0| :   2%|▏           | 600/30000 [00:12<15:02, 32.56it/s]Step 600: 5407 GSs duplicated, 330 GSs split. Now having 189273 GSs.
# Step 600: 131 GSs pruned. Now having 189142 GSs.
# loss=0.087| sh degree=0| :   2%|▎           | 690/30000 [00:13<06:02, 80.79it/s]Step 700: 10741 GSs duplicated, 329 GSs split. Now having 200212 GSs.
# Step 700: 111 GSs pruned. Now having 200101 GSs.
# loss=0.083| sh degree=0| :   3%|▎          | 791/30000 [00:15<04:44, 102.55it/s]Step 800: 13339 GSs duplicated, 375 GSs split. Now having 213815 GSs.
# Step 800: 86 GSs pruned. Now having 213729 GSs.
# loss=0.112| sh degree=0| :   3%|▎           | 893/30000 [00:16<05:57, 81.42it/s]Step 900: 11580 GSs duplicated, 541 GSs split. Now having 225850 GSs.
# Step 900: 121 GSs pruned. Now having 225729 GSs.
# ...

# %% [markdown]
# ### 3DGS Default mode - Viewer

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_viewer.py \
#     --ckpt ./temp_results/WhitePass_Train_default_factor_4/ckpts/ckpt_29999_rank0.pt

# %% [markdown]
# ## 3DGS  3DGUT mode

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_trainer.py mcmc --with_ut --with_eval3d  \
    --data_dir ./temp_data/WhitePass_Train_seq/ --data_factor 4\
    --result_dir ./temp_results/WhitePass_Train_seq_3dgut_factor_4 --save_ply --disable_viewer
# Out:
# [Parser] 550 images, taken by 1 cameras.
# ...
# Scene scale: 2.2040180200210973
# Model initialized. Number of GS: 183536
# loss=0.294| sh degree=0| :   2%|▏           | 599/30000 [00:18<14:41, 33.36it/s]Step 600: Relocated 38314 GSs.
# Step 600: Added 9176 GSs. Now having 192712 GSs.
# loss=0.157| sh degree=0| :   2%|▎          | 690/30000 [00:19<04:24, 110.67it/s]Step 700: Relocated 19685 GSs.
# Step 700: Added 9635 GSs. Now having 202347 GSs.
# loss=0.127| sh degree=0| :   3%|▎          | 791/30000 [00:19<04:00, 121.60it/s]Step 800: Relocated 22533 GSs.
# Step 800: Added 10117 GSs. Now having 212464 GSs.
# loss=0.162| sh degree=0| :   3%|▎          | 900/30000 [00:20<04:21, 111.35it/s]Step 900: Relocated 23435 GSs.
# Step 900: Added 10623 GSs. Now having 223087 GSs.
# loss=0.138| sh degree=1| :   3%|▍           | 996/30000 [00:22<09:49, 49.21it/s]Step 1000: Relocated 22451 GSs.
# Step 1000: Added 11154 GSs. Now having 234241 GSs.
# ...

# %% [markdown]
# ### 3DGS  3DGUT mode - Viewer

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_viewer_3dgut.py \
#     --ckpt ./temp_results/WhitePass_Train_3dgut_factor_4/ckpts/ckpt_29999_rank0.pt

# %% [markdown]
# ## 3DGS MCMC(Markov Chain MonteCarlo) mode

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_trainer.py mcmc \
    --data_dir ./temp_data/WhitePass_Train_seq/ --data_factor 4\
    --result_dir ./temp_results/WhitePass_Train_seq_mcmc_factor_4 --save_ply --disable_viewer
# Out:
# [Parser] 550 images, taken by 1 cameras.
# ...
# Scene scale: 2.2040180200210973
# Model initialized. Number of GS: 183536
# loss=0.235| sh degree=0| :   2%|▏           | 597/30000 [00:18<17:15, 28.38it/s]Step 600: Relocated 4955 GSs.
# Step 600: Added 9176 GSs. Now having 192712 GSs.
# loss=0.179| sh degree=0| :   2%|▎           | 696/30000 [00:21<08:59, 54.28it/s]Step 700: Relocated 4495 GSs.
# Step 700: Added 9635 GSs. Now having 202347 GSs.
# loss=0.108| sh degree=0| :   3%|▎           | 799/30000 [00:24<16:00, 30.40it/s]Step 800: Relocated 6183 GSs.
# Step 800: Added 10117 GSs. Now having 212464 GSs.
# loss=0.132| sh degree=0| :   3%|▎           | 900/30000 [00:27<10:13, 47.41it/s]Step 900: Relocated 7499 GSs.
# Step 900: Added 10623 GSs. Now having 223087 GSs.
# loss=0.125| sh degree=1| :   3%|▎          | 1000/30000 [00:29<15:50, 30.52it/s]Step 1000: Relocated 9197 GSs.
# Step 1000: Added 11154 GSs. Now having 234241 GSs.
# ...

# %% [markdown]
# ### 3DGS MCMC mode - Viewer

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_viewer.py  \
#     --ckpt ./temp_results/WhitePass_Train_mcmc_factor_4/ckpts/ckpt_29999_rank0.pt

# %% [markdown]
# ## 3DGS 2DGS mode

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_trainer_2dgs.py \
    --data_dir ./temp_data/WhitePass_Train_seq/ --data_factor 4\
    --result_dir ./temp_results/WhitePass_Train_seq_2dgs_factor_4 --disable_viewer
# Out:
# [Parser] 550 images, taken by 1 cameras.
# ...
# Scene scale: 2.2040180200210973
# Model initialized. Number of GS: 183536
# loss=0.143| sh degree=0| :   2%|▏           | 599/30000 [00:28<25:05, 19.53it/s]Step 600: 6787 GSs duplicated, 2325 GSs split. Now having 192648 GSs.
# Step 600: 38920 GSs pruned. Now having 153728 GSs.
# loss=0.094| sh degree=0| :   2%|▎           | 699/30000 [00:33<21:39, 22.54it/s]Step 700: 11563 GSs duplicated, 2020 GSs split. Now having 167311 GSs.
# Step 700: 5880 GSs pruned. Now having 161431 GSs.
# loss=0.094| sh degree=0| :   3%|▎           | 797/30000 [00:37<16:53, 28.82it/s]Step 800: 14382 GSs duplicated, 2128 GSs split. Now having 177941 GSs.
# Step 800: 4658 GSs pruned. Now having 173283 GSs.
# loss=0.103| sh degree=0| :   3%|▎           | 898/30000 [00:41<21:31, 22.53it/s]Step 900: 13911 GSs duplicated, 2098 GSs split. Now having 189292 GSs.
# Step 900: 6046 GSs pruned. Now having 183246 GSs.
# ...

# %% [markdown]
# ### 3DGS  2DGS mode - Viewer

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_viewer_2dgs.py \
#     --ckpt ./temp_results/WhitePass_Train_2dgs_factor_4/ckpts/ckpt_6999.pt
