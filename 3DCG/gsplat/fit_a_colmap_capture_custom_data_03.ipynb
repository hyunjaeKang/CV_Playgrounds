# %% [markdown]
# # gsplat :: Custom data :: Celebrity_Gym
#
# - Conda env : [gsplat](README.md#setup-a-conda-environment)

# %%
# !nvidia-smi
# Out:
# Mon Sep 29 14:20:46 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 575.57.08              Driver Version: 575.57.08      CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 2080 Ti     On  |   00000000:01:00.0  On |                  N/A |
# | 26%   46C    P5             36W /  250W |    2349MiB /  11264MiB |     22%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# ## Download data

# %%
import gdown


id = "1jx1jtZQnxe1lmzzKQTBKuffmic4Did62"
vid_path = "./temp_data/Celebrity_Gym.mov"

gdown.download(id=id, output = vid_path)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1jx1jtZQnxe1lmzzKQTBKuffmic4Did62
# To: /home/hyunjae/110_HyunJae_Git/2025_Playgrounds/CV_Playgrounds/3DCG/gsplat/temp_data/Celebrity_Gym.mov
# 100%|██████████| 16.9M/16.9M [00:02<00:00, 6.65MB/s]
# './temp_data/Celebrity_Gym.mov'

# %%
# !python ./utils/video2imgs.py --video_path "./temp_data/Celebrity_Gym.mov" --output_dir "./temp_data/Celebrity_Gym_seq/images" --fps 10
# Out:
# Saved 154 frames at 10.0 fps to './temp_data/Celebrity_Gym_seq/images'.

# %%
# !python ./utils/imgs2poses.py --data_dir "./temp_data/Celebrity_Gym_seq" --factor 4
# Out:
# Need to run COLMAP
# Features extracted
# Features matched
# Sparse map created
# Finished running COLMAP, see ./temp_data/Celebrity_Gym_seq/colmap_output.txt for logs
# Post-colmap
# Cameras 5
# Images # 154
# Points (10508, 3) Visibility (10508, 154)
# Depth stats 0.047995620341853465 195.14797791782306 10.633094113255437
# Factors: [4]
# Minifying 4 ./temp_data/Celebrity_Gym_seq
# mogrify -resize 25% -format png *.jpg
# Removed duplicates
# Done
# Done with imgs2poses

# %% [markdown]
# ## 3DGS Default mode

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_trainer.py default \
    --data_dir ./temp_data/Celebrity_Gym_seq/ --data_factor 4\
    --result_dir ./temp_results/Celebrity_Gym_seq_default_factor_4 --save_ply --disable_viewer
# Out:
# [Parser] 154 images, taken by 1 cameras.
# ...
# Scene scale: 1.9426115986014383
# Model initialized. Number of GS: 10508
# loss=0.072| sh degree=0| :   2%|▏           | 595/30000 [00:10<13:43, 35.70it/s]Step 600: 934 GSs duplicated, 3759 GSs split. Now having 15201 GSs.
# Step 600: 636 GSs pruned. Now having 14565 GSs.
# loss=0.047| sh degree=0| :   2%|▎          | 690/30000 [00:11<04:20, 112.41it/s]Step 700: 2805 GSs duplicated, 5443 GSs split. Now having 22813 GSs.
# Step 700: 252 GSs pruned. Now having 22561 GSs.
# loss=0.029| sh degree=0| :   3%|▎           | 793/30000 [00:12<07:12, 67.51it/s]Step 800: 5752 GSs duplicated, 6750 GSs split. Now having 35063 GSs.
# Step 800: 161 GSs pruned. Now having 34902 GSs.
# loss=0.030| sh degree=0| :   3%|▎           | 898/30000 [00:15<15:30, 31.27it/s]Step 900: 9006 GSs duplicated, 7413 GSs split. Now having 51321 GSs.
# Step 900: 178 GSs pruned. Now having 51143 GSs.
# ...

# %% [markdown]
# ### 3DGS Default mode - Viewer

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_viewer.py \
#     --ckpt ./temp_results/Celebrity_Gym_default_factor_4/ckpts/ckpt_29999_rank0.pt

# %% [markdown]
# ## 3DGS  3DGUT mode

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_trainer.py mcmc --with_ut --with_eval3d  \
    --data_dir ./temp_data/Celebrity_Gym_seq/ --data_factor 4\
    --result_dir ./temp_results/Celebrity_Gym_seq_3dgut_factor_4 --save_ply --disable_viewer
# Out:
# [Parser] 154 images, taken by 1 cameras.
# ...
# Scene scale: 1.9426115986014383
# Model initialized. Number of GS: 10508
# loss=0.122| sh degree=0| :   2%|▏           | 598/30000 [00:16<15:03, 32.54it/s]Step 600: Relocated 1763 GSs.
# Step 600: Added 525 GSs. Now having 11033 GSs.
# loss=0.079| sh degree=0| :   2%|▎           | 697/30000 [00:19<14:14, 34.31it/s]Step 700: Relocated 408 GSs.
# Step 700: Added 551 GSs. Now having 11584 GSs.
# loss=0.050| sh degree=0| :   3%|▎           | 797/30000 [00:22<14:55, 32.62it/s]Step 800: Relocated 310 GSs.
# Step 800: Added 579 GSs. Now having 12163 GSs.
# loss=0.046| sh degree=0| :   3%|▎           | 899/30000 [00:25<15:42, 30.88it/s]Step 900: Relocated 326 GSs.
# Step 900: Added 608 GSs. Now having 12771 GSs.
# loss=0.042| sh degree=1| :   3%|▍           | 999/30000 [00:28<15:19, 31.52it/s]Step 1000: Relocated 343 GSs.
# Step 1000: Added 638 GSs. Now having 13409 GSs.
# ...

# %% [markdown]
# ### 3DGS  3DGUT mode - Viewer

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_viewer_3dgut.py \
#     --ckpt ./temp_results/Celebrity_Gym_3dgut_factor_4/ckpts/ckpt_29999_rank0.pt

# %% [markdown]
# ## 3DGS MCMC(Markov Chain MonteCarlo) mode

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_trainer.py mcmc \
    --data_dir ./temp_data/Celebrity_Gym_seq/ --data_factor 4\
    --result_dir ./temp_results/Celebrity_Gym_seq_factor_4 --save_ply --disable_viewer
# Out:
# [Parser] 154 images, taken by 1 cameras.
# ...
# Scene scale: 1.9426115986014383
# Model initialized. Number of GS: 10508
# loss=0.120| sh degree=0| :   2%|▏           | 598/30000 [00:15<10:34, 46.34it/s]Step 600: Relocated 327 GSs.
# Step 600: Added 525 GSs. Now having 11033 GSs.
# loss=0.080| sh degree=0| :   2%|▎           | 699/30000 [00:18<15:15, 32.02it/s]Step 700: Relocated 150 GSs.
# Step 700: Added 551 GSs. Now having 11584 GSs.
# loss=0.051| sh degree=0| :   3%|▎           | 797/30000 [00:21<13:31, 36.00it/s]Step 800: Relocated 185 GSs.
# Step 800: Added 579 GSs. Now having 12163 GSs.
# loss=0.049| sh degree=0| :   3%|▎           | 899/30000 [00:24<13:54, 34.87it/s]Step 900: Relocated 156 GSs.
# Step 900: Added 608 GSs. Now having 12771 GSs.
# loss=0.043| sh degree=1| :   3%|▍           | 999/30000 [00:26<13:20, 36.23it/s]Step 1000: Relocated 195 GSs.
# Step 1000: Added 638 GSs. Now having 13409 GSs.
# ...

# %% [markdown]
# ### 3DGS MCMC mode - Viewer

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_viewer.py  \
#     --ckpt ./temp_results/Celebrity_Gym_factor_4/ckpts/ckpt_29999_rank0.pt

# %% [markdown]
# ## 3DGS 2DGS mode

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_trainer_2dgs.py \
    --data_dir ./temp_data/Celebrity_Gym_seq/ --data_factor 4\
    --result_dir ./temp_results/Celebrity_Gym_seq_2dgs_factor_4 --disable_viewer
# Out:
# [Parser] 154 images, taken by 1 cameras.
# ...
# Scene scale: 1.9426115986014383
# Model initialized. Number of GS: 10508
# loss=0.076| sh degree=0| :   2%|▏           | 600/30000 [00:26<17:40, 27.72it/s]Step 600: 100 GSs duplicated, 5235 GSs split. Now having 15843 GSs.
# Step 600: 3209 GSs pruned. Now having 12634 GSs.
# loss=0.051| sh degree=0| :   2%|▎           | 699/30000 [00:31<22:39, 21.55it/s]Step 700: 673 GSs duplicated, 8703 GSs split. Now having 22010 GSs.
# Step 700: 828 GSs pruned. Now having 21182 GSs.
# loss=0.032| sh degree=0| :   3%|▎           | 799/30000 [00:35<21:05, 23.07it/s]Step 800: 2181 GSs duplicated, 11254 GSs split. Now having 34617 GSs.
# Step 800: 1668 GSs pruned. Now having 32949 GSs.
# loss=0.035| sh degree=0| :   3%|▎           | 900/30000 [00:39<10:23, 46.67it/s]Step 900: 4264 GSs duplicated, 13097 GSs split. Now having 50310 GSs.
# Step 900: 1843 GSs pruned. Now having 48467 GSs.
# ...

# %% [markdown]
# ### 3DGS  2DGS mode - Viewer

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_viewer_2dgs.py \
#     --ckpt ./temp_results/Celebrity_Gym_2dgs_factor_4/ckpts/ckpt_29999.pt
