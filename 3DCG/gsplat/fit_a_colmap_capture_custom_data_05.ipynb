# %% [markdown]
# # gsplat :: Custom data :: Celebrity_Edge_GradPlaza_2
#
# - Conda env : [gsplat](README.md#setup-a-conda-environment)

# %%
# !nvidia-smi
# Out:
# Mon Sep 29 14:21:02 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 575.57.08              Driver Version: 575.57.08      CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 2080 Ti     On  |   00000000:01:00.0  On |                  N/A |
# | 26%   46C    P5             35W /  250W |    2428MiB /  11264MiB |     22%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# ## Download data

# %%
import gdown

id = "1SnKE3e-2EDU1ocYfDes3GIC4Zmmd4rSI"
vid_path = "./temp_data/Celebrity_Edge_GradPlaza_2.mov"

gdown.download(id=id, output = vid_path)

# %%
proj="Celebrity_Edge_GradPlaza_2"
factor=4

# %%
# !python ./utils/video2imgs.py --video_path "./temp_data/Celebrity_Edge_GradPlaza_2.mov" --output_dir "./temp_data/Celebrity_Edge_GradPlaza_2/images" --fps 1


# !python ./utils/video2imgs.py --video_path ./temp_data/Celebrity_Edge_GradPlaza_2.mov --output_dir ./temp_data/$proj/images --fps 10
# Out:
# Saved 316 frames at 10.0 fps to './temp_data/Celebity_Edge_GradPlaza_2/images'.

# %%
# !python ./utils/imgs2poses.py --help
# Out:
# usage: imgs2poses.py [-h] [--match_type MATCH_TYPE] [--data_dir DATA_DIR]
#                      [--factor FACTOR]
#
# options:
#   -h, --help            show this help message and exit
#   --match_type MATCH_TYPE
#                         type of matcher used. Valid options:
#                         exhaustive_matcher sequential_matcher. Other matchers
#                         not supported at this time
#   --data_dir DATA_DIR   input scene directory
#   --factor FACTOR       factor by which the image dimention should reduce

# %%
# !python ./utils/imgs2poses.py --data_dir ./temp_data/$proj --factor=$factor --match_type sequential_matcher
# Out:
# Need to run COLMAP
# Features extracted
# Features matched
# Sparse map created
# Finished running COLMAP, see ./temp_data/Celebity_Edge_GradPlaza_2/colmap_output.txt for logs
# Post-colmap
# Cameras 5
# Images # 146
# ERROR: the correct camera poses for current points cannot be accessed
# Factors: [4]
# Minifying 4 ./temp_data/Celebity_Edge_GradPlaza_2
# mogrify -resize 25% -format png *.jpg
# Removed duplicates
# Done
# Done with imgs2poses

# %% [markdown]
# ## 3DGS Default mode

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_trainer.py default \
    --data_dir ./temp_data/Celebrity_Edge_GradPlaza_2/ --data_factor 4\
    --result_dir ./temp_results/Celebrity_Edge_GradPlaza_2_default_factor_4 --save_ply --disable_viewer
# Out:
# [Parser] 146 images, taken by 1 cameras.
# ...
# Scene scale: 83.10293950512113
# Model initialized. Number of GS: 164
# loss=0.277| sh degree=0| :   2%|▏           | 597/30000 [00:17<14:23, 34.06it/s]Step 600: 49 GSs duplicated, 24 GSs split. Now having 237 GSs.
# Step 600: 0 GSs pruned. Now having 237 GSs.
# loss=0.248| sh degree=0| :   2%|▎           | 700/30000 [00:19<14:30, 33.66it/s]Step 700: 71 GSs duplicated, 40 GSs split. Now having 348 GSs.
# Step 700: 1 GSs pruned. Now having 347 GSs.
# loss=0.249| sh degree=0| :   3%|▎           | 797/30000 [00:22<14:24, 33.77it/s]Step 800: 104 GSs duplicated, 67 GSs split. Now having 518 GSs.
# Step 800: 7 GSs pruned. Now having 511 GSs.
# loss=0.227| sh degree=0| :   3%|▎           | 898/30000 [00:24<07:08, 67.92it/s]Step 900: 152 GSs duplicated, 108 GSs split. Now having 771 GSs.
# Step 900: 6 GSs pruned. Now having 765 GSs.
# ...

# %% [markdown]
# ### 3DGS Default mode - Viewer

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_viewer.py \
#     --ckpt ./temp_results/garden_default/ckpts/ckpt_6999_rank0.pt 

CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_viewer.py --ckpt ./temp_results/Celebrity_Edge_GradPlaza_2_default_factor_4/ckpts/ckpt_6999_rank0.pt

# %% [markdown]
# ## 3DGS  3DGUT mode

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_trainer.py mcmc --with_ut --with_eval3d  \
    --data_dir ./temp_data/Celebrity_Edge_GradPlaza_2/ --data_factor 4\
    --result_dir ./temp_results/Celebrity_Edge_GradPlaza_2_3dgut_factor_4 --save_ply --disable_viewer
# Out:
# [Parser] 146 images, taken by 1 cameras.
# ...
# Scene scale: 83.10293950512113
# Model initialized. Number of GS: 164
# loss=0.322| sh degree=0| :   2%|▏           | 597/30000 [00:16<14:19, 34.23it/s]Step 600: Relocated 96 GSs.
# Step 600: Added 8 GSs. Now having 172 GSs.
# loss=0.269| sh degree=0| :   2%|▎           | 698/30000 [00:20<13:58, 34.94it/s]Step 700: Relocated 19 GSs.
# Step 700: Added 8 GSs. Now having 180 GSs.
# loss=0.267| sh degree=0| :   3%|▎           | 799/30000 [00:23<15:10, 32.06it/s]Step 800: Relocated 19 GSs.
# Step 800: Added 9 GSs. Now having 189 GSs.
# loss=0.261| sh degree=0| :   3%|▎           | 898/30000 [00:25<15:53, 30.52it/s]Step 900: Relocated 28 GSs.
# Step 900: Added 9 GSs. Now having 198 GSs.
# loss=0.264| sh degree=1| :   3%|▍           | 998/30000 [00:28<13:01, 37.09it/s]Step 1000: Relocated 28 GSs.
# Step 1000: Added 9 GSs. Now having 207 GSs.
# ...

# %% [markdown]
# ### 3DGS  3DGUT mode - Viewer

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_viewer_3dgut.py --ckpt ./temp_results/Celebrity_Edge_GradPlaza_2_3dgut_factor_4/ckpts/ckpt_29999_rank0.pt

# %% [markdown]
# ## 3DGS MCMC(Markov Chain MonteCarlo) mode

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_trainer.py mcmc \
    --data_dir ./temp_data/Celebrity_Edge_GradPlaza_2/ --data_factor 4\
    --result_dir ./temp_results/Celebrity_Edge_GradPlaza_2_mcmc_factor_4 --save_ply --disable_viewer
# Out:
# [Parser] 146 images, taken by 1 cameras.
# ...
# Scene scale: 83.10293950512113
# Model initialized. Number of GS: 164
# loss=0.278| sh degree=0| :   2%|▏           | 597/30000 [00:15<14:41, 33.37it/s]Step 600: Relocated 94 GSs.
# Step 600: Added 8 GSs. Now having 172 GSs.
# loss=0.257| sh degree=0| :   2%|▎           | 691/30000 [00:17<06:28, 75.49it/s]Step 700: Relocated 12 GSs.
# Step 700: Added 8 GSs. Now having 180 GSs.
# loss=0.261| sh degree=0| :   3%|▎           | 797/30000 [00:20<14:58, 32.50it/s]Step 800: Relocated 18 GSs.
# Step 800: Added 9 GSs. Now having 189 GSs.
# loss=0.252| sh degree=0| :   3%|▎           | 896/30000 [00:22<10:41, 45.39it/s]Step 900: Relocated 19 GSs.
# Step 900: Added 9 GSs. Now having 198 GSs.
# loss=0.256| sh degree=1| :   3%|▍           | 989/30000 [00:25<10:19, 46.86it/s]Step 1000: Relocated 17 GSs.
# Step 1000: Added 9 GSs. Now having 207 GSs.
# ...

# %% [markdown]
# ### 3DGS MCMC mode - Viewer

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_viewer.py  --ckpt ./temp_results/Celebrity_Edge_GradPlaza_2_mcmc_factor_4/ckpts/ckpt_29999_rank0.pt

# %% [markdown]
# ## 3DGS 2DGS mode

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_trainer_2dgs.py \
    --data_dir ./temp_data/Celebrity_Edge_GradPlaza_2/ --data_factor 4\
    --result_dir ./temp_results/Celebrity_Edge_GradPlaza_2_2dgs_factor_4 --disable_viewer
# Out:
# [Parser] 146 images, taken by 1 cameras.
# ...
# Scene scale: 83.10293950512113
# Model initialized. Number of GS: 164
# loss=0.277| sh degree=0| :   2%|▏           | 595/30000 [00:22<17:21, 28.25it/s]Step 600: 2 GSs duplicated, 67 GSs split. Now having 233 GSs.
# Step 600: 63 GSs pruned. Now having 170 GSs.
# loss=0.260| sh degree=0| :   2%|▎           | 700/30000 [00:26<12:55, 37.77it/s]Step 700: 0 GSs duplicated, 76 GSs split. Now having 246 GSs.
# Step 700: 28 GSs pruned. Now having 218 GSs.
# loss=0.256| sh degree=0| :   3%|▎           | 800/30000 [00:30<20:46, 23.42it/s]Step 800: 0 GSs duplicated, 113 GSs split. Now having 331 GSs.
# Step 800: 19 GSs pruned. Now having 312 GSs.
# loss=0.231| sh degree=0| :   3%|▎           | 899/30000 [00:33<10:40, 45.46it/s]Step 900: 0 GSs duplicated, 184 GSs split. Now having 496 GSs.
# Step 900: 35 GSs pruned. Now having 461 GSs.
# ...

# %% [markdown]
# ### 3DGS  2DGS mode - Viewer

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_viewer_2dgs.py \
#     --ckpt ./temp_results/garden_2dgs/ckpts/ckpt_29999.pt
