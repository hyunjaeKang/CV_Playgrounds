# %% [markdown]
# # gsplat :: Custom data :: Celebity_Edge_GradPlaza
#
# - Conda env : [gsplat](README.md#setup-a-conda-environment)

# %%
# !nvidia-smi
# Out:
# Mon Sep 29 14:20:53 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 575.57.08              Driver Version: 575.57.08      CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 2080 Ti     On  |   00000000:01:00.0  On |                  N/A |
# | 26%   46C    P5             33W /  250W |    2451MiB /  11264MiB |     34%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# ## Download data

# %%
import gdown

id = "1T6naoj4bNRZOdoKjLmI3WAd1cp-NBCTR"
vid_path = "./temp_data/Celebity_Edge_GradPlaza.mov"

gdown.download(id=id, output = vid_path)

# %%
proj = "Celebity_Edge_GradPlaza_img_rot_90"
factor=4

# %%
# !python ./utils/video2imgs.py --video_path ./temp_data/Celebity_Edge_GradPlaza.mov \
        --output_dir ./temp_data/Celebity_Edge_GradPlaza_img_rot_90/images --fps 10 --img_rotate 1
# Out:
# Saved 253 frames at 10.0 fps to './temp_data/Celebity_Edge_GradPlaza_img_rot_90/images'.

# %%
# !python ./utils/imgs2poses.py --data_dir ./temp_data/Celebity_Edge_GradPlaza_img_rot_90 --factor 4 --match_type sequential_matcher
# Out:
# Need to run COLMAP
# Features extracted
# Features matched
# Sparse map created
# Finished running COLMAP, see ./temp_data/Celebity_Edge_GradPlaza_img_rot_90/colmap_output.txt for logs
# Post-colmap
# Cameras 5
# Images # 20
# ERROR: the correct camera poses for current points cannot be accessed
# Factors: [4]
# Minifying 4 ./temp_data/Celebity_Edge_GradPlaza_img_rot_90
# mogrify -resize 25% -format png *.jpg
# Removed duplicates
# Done
# Done with imgs2poses

# %% [markdown]
# ## 3DGS Default mode

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_trainer.py default \
    --data_dir ./temp_data/Celebity_Edge_GradPlaza_img_rot_90/ --data_factor 4\
    --result_dir ./temp_results/Celebity_Edge_GradPlaza_img_rot_90_default_factor_4 --save_ply --disable_viewer
# Out:
# [Parser] 20 images, taken by 1 cameras.
# ...
# Scene scale: 7.466038968055737
# Model initialized. Number of GS: 22
# loss=0.241| sh degree=0| :   2%|▏          | 596/30000 [00:17<04:40, 104.76it/s]Step 600: 0 GSs duplicated, 16 GSs split. Now having 38 GSs.
# Step 600: 0 GSs pruned. Now having 38 GSs.
# loss=0.228| sh degree=0| :   2%|▎          | 689/30000 [00:19<04:39, 104.89it/s]Step 700: 0 GSs duplicated, 26 GSs split. Now having 64 GSs.
# Step 700: 0 GSs pruned. Now having 64 GSs.
# loss=0.243| sh degree=0| :   3%|▎           | 797/30000 [00:20<10:11, 47.77it/s]Step 800: 0 GSs duplicated, 39 GSs split. Now having 103 GSs.
# Step 800: 3 GSs pruned. Now having 100 GSs.
# loss=0.230| sh degree=0| :   3%|▎           | 899/30000 [00:23<10:44, 45.18it/s]Step 900: 0 GSs duplicated, 65 GSs split. Now having 165 GSs.
# Step 900: 0 GSs pruned. Now having 165 GSs.
# ...

# %% [markdown]
# ### 3DGS Default mode - Viewer

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_viewer.py \
# --ckpt ./temp_results/Celebity_Edge_GradPlaza_img_rot_90_default_factor_4/ckpts/ckpt_29999_rank0.pt
# Out:
# Number of Gaussians: 1265899
# ╭──────────────── viser ────────────────╮
# │             ╷                         │
# │   HTTP      │ http://localhost:8080   │
# │   Websocket │ ws://localhost:8080     │
# │             ╵                         │
# ╰───────────────────────────────────────╯
# Viewer running... Ctrl+C to exit.
# Traceback (most recent call last):
#   File "/home/hyunjae/110_HyunJae_Git/2025_Playgrounds/CV_Playgrounds/3DCG/gsplat/./temp_gsplat/examples/simple_viewer.py", line 248, in <module>
#     cli(main, args, verbose=True)
#   File "/home/hyunjae/110_HyunJae_Git/2025_Playgrounds/CV_Playgrounds/3DCG/gsplat/temp_gsplat/gsplat/distributed.py", line 360, in cli
#     return _distributed_worker(0, 1, fn=fn, args=args)
#   File "/home/hyunjae/110_HyunJae_Git/2025_Playgrounds/CV_Playgrounds/3DCG/gsplat/temp_gsplat/gsplat/distributed.py", line 295, in _distributed_worker
#     fn(local_rank, world_rank, world_size, args)
# ...

# %% [markdown]
# ## 3DGS  3DGUT mode

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_trainer.py mcmc --with_ut --with_eval3d  \
    --data_dir ./temp_data/Celebity_Edge_GradPlaza_img_rot_90/ --data_factor 4\
    --result_dir ./temp_results/Celebity_Edge_GradPlaza_img_rot_90_3dgut_factor_4 --save_ply --disable_viewer
# Out:
# [Parser] 20 images, taken by 1 cameras.
# ...
# Scene scale: 7.466038968055737
# Model initialized. Number of GS: 22
# loss=0.264| sh degree=0| :   2%|▏           | 597/30000 [00:18<16:41, 29.36it/s]Step 600: Relocated 5 GSs.
# Step 600: Added 1 GSs. Now having 23 GSs.
# loss=0.257| sh degree=0| :   2%|▎           | 698/30000 [00:21<16:09, 30.22it/s]Step 700: Relocated 1 GSs.
# Step 700: Added 1 GSs. Now having 24 GSs.
# loss=0.270| sh degree=0| :   3%|▎           | 800/30000 [00:24<15:38, 31.13it/s]Step 800: Relocated 1 GSs.
# Step 800: Added 1 GSs. Now having 25 GSs.
# loss=0.259| sh degree=0| :   3%|▎           | 900/30000 [00:27<12:48, 37.85it/s]Step 900: Relocated 1 GSs.
# Step 900: Added 1 GSs. Now having 26 GSs.
# loss=0.255| sh degree=1| :   3%|▎          | 1000/30000 [00:30<13:37, 35.46it/s]Step 1000: Relocated 0 GSs.
# Step 1000: Added 1 GSs. Now having 27 GSs.
# loss=0.261| sh degree=1| :   4%|▍          | 1097/30000 [00:34<15:04, 31.97it/s]Step 1100: Relocated 2 GSs.
# ...

# %% [markdown]
# ### 3DGS  3DGUT mode - Viewer

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_viewer_3dgut.py \
#     --ckpt ./temp_results/Celebity_Edge_GradPlaza_3dgut_factor_4/ckpts/ckpt_29999_rank0.pt

# %% [markdown]
# ## 3DGS MCMC(Markov Chain MonteCarlo) mode

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_trainer.py mcmc \
    --data_dir ./temp_data/Celebity_Edge_GradPlaza_img_rot_90/ --data_factor 4\
    --result_dir ./temp_results/Celebity_Edge_GradPlaza_img_rot_90_default_mcmc_4 --save_ply --disable_viewer
# Out:
# [Parser] 20 images, taken by 1 cameras.
# ...
# Scene scale: 7.466038968055737
# Model initialized. Number of GS: 22
# loss=0.265| sh degree=0| :   2%|▏           | 600/30000 [00:18<16:02, 30.54it/s]Step 600: Relocated 5 GSs.
# Step 600: Added 1 GSs. Now having 23 GSs.
# loss=0.256| sh degree=0| :   2%|▎           | 698/30000 [00:21<16:49, 29.01it/s]Step 700: Relocated 1 GSs.
# Step 700: Added 1 GSs. Now having 24 GSs.
# loss=0.268| sh degree=0| :   3%|▎           | 800/30000 [00:24<15:56, 30.53it/s]Step 800: Relocated 1 GSs.
# Step 800: Added 1 GSs. Now having 25 GSs.
# loss=0.263| sh degree=0| :   3%|▎           | 899/30000 [00:27<13:33, 35.79it/s]Step 900: Relocated 0 GSs.
# Step 900: Added 1 GSs. Now having 26 GSs.
# loss=0.256| sh degree=1| :   3%|▍           | 996/30000 [00:30<14:39, 32.98it/s]Step 1000: Relocated 0 GSs.
# Step 1000: Added 1 GSs. Now having 27 GSs.
# loss=0.264| sh degree=1| :   4%|▍          | 1097/30000 [00:33<14:22, 33.50it/s]Step 1100: Relocated 1 GSs.
# ...

# %% [markdown]
# ### 3DGS MCMC mode - Viewer

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_viewer.py  \
#     --ckpt ./temp_results/Celebity_Edge_GradPlaza_mcmc_factor_4/ckpts/ckpt_29999_rank0.pt

# %% [markdown]
# ## 3DGS 2DGS mode

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_trainer_2dgs.py \
    --data_dir ./temp_data/Celebity_Edge_GradPlaza_img_rot_90/ --data_factor 4\
    --result_dir ./temp_results/Celebity_Edge_GradPlaza_img_rot_90_2dgs_factor_4 --disable_viewer
# Out:
# [Parser] 20 images, taken by 1 cameras.
# ...
# Scene scale: 7.466038968055737
# Model initialized. Number of GS: 22
# loss=0.241| sh degree=0| :   2%|▏           | 600/30000 [00:27<23:06, 21.21it/s]Step 600: 0 GSs duplicated, 18 GSs split. Now having 40 GSs.
# Step 600: 10 GSs pruned. Now having 30 GSs.
# loss=0.229| sh degree=0| :   2%|▎           | 698/30000 [00:31<24:27, 19.97it/s]Step 700: 0 GSs duplicated, 24 GSs split. Now having 54 GSs.
# Step 700: 3 GSs pruned. Now having 51 GSs.
# loss=0.243| sh degree=0| :   3%|▎           | 800/30000 [00:35<24:47, 19.62it/s]Step 800: 0 GSs duplicated, 36 GSs split. Now having 87 GSs.
# Step 800: 13 GSs pruned. Now having 74 GSs.
# loss=0.231| sh degree=0| :   3%|▎           | 900/30000 [00:39<21:58, 22.07it/s]Step 900: 0 GSs duplicated, 52 GSs split. Now having 126 GSs.
# Step 900: 16 GSs pruned. Now having 110 GSs.
# ...

# %% [markdown]
# ### 3DGS  2DGS mode - Viewer

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./temp_gsplat/examples/simple_viewer_2dgs.py \
#     --ckpt ./temp_results/Celebity_Edge_GradPlaza_2dgs_factor_4/ckpts/ckpt_29999.pt
